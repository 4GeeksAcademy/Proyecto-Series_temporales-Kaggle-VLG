# %% [markdown]
# # Explore here

# %%
# Your code here

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from pmdarima import auto_arima


import warnings
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#      10 from statsmodels.tsa.stattools import adfuller
#      11 from statsmodels.graphics.tsaplots import plot_acf
# ---> 12 from pmdarima import auto_arima
#      15 import warnings
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/arima/approx.py:9
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       4 #
#       5 # R approx function
#       7 import numpy as np
# ----> 9 from ..utils.array import c, check_endog
#      10 from ..utils import get_callable
#      11 from ..compat.numpy import DTYPE
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/utils/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .array import *
#       6 from .metaestimators import *
#       7 from .visualization import *
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/utils/array.py:13
#      10 import pandas as pd
#      12 from ..compat import DTYPE
# ---> 13 from ._array import C_intgrt_vec
#      15 __all__ = [
#      16     'as_series',
#      17     'c',
#    (...)
#      22     'is_iterable'
#      23 ]
#      26 def as_series(x, **kwargs):
#
# File pmdarima/utils/_array.pyx:1, in init pmdarima.utils._array()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
#Aquifer_aufer=pd.read_csv("C:\Users\victo\OneDrive\Escritorio\4Geeks\acea-water-prediction\Aquifer_Auser.csv")
df=pd.read_csv("/workspaces/Proyecto-Series_temporales-Kaggle-VLG/Aquifer_Petrignano.csv")
df
# Out:
#             Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0     14/03/2006                    NaN                    -22.48
# 1     15/03/2006                    NaN                    -22.38
# 2     16/03/2006                    NaN                    -22.25
# 3     17/03/2006                    NaN                    -22.38
# 4     18/03/2006                    NaN                    -22.60
# ...          ...                    ...                       ...
# 5218  26/06/2020                    0.0                    -25.68
# 5219  27/06/2020                    0.0                    -25.80
# 5220  28/06/2020                    0.0                    -25.80
# 5221  29/06/2020                    0.0                    -25.78
# 5222  30/06/2020                    0.0                    -25.91
#
#       Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# 0                       -22.18                       NaN
# 1                       -22.14                       NaN
# 2                       -22.04                       NaN
# 3                       -22.04                       NaN
# 4                       -22.04                       NaN
# ...                        ...                       ...
# 5218                    -25.07                      25.7
# 5219                    -25.11                      26.2
# 5220                    -25.19                      26.9
# 5221                    -25.18                      26.9
# 5222                    -25.25                      27.3
#
#       Temperature_Petrignano  Volume_C10_Petrignano  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# ...                      ...                    ...
# 5218                    24.5             -29930.688
# 5219                    25.0             -31332.960
# 5220                    25.7             -32120.928
# 5221                    26.0             -30602.880
# 5222                    26.5             -31878.144
#
#       Hydrometry_Fiume_Chiascio_Petrignano
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 5218                                   2.5
# 5219                                   2.4
# 5220                                   2.4
# 5221                                   2.4
# 5222                                   2.4
#
# [5223 rows x 8 columns]
